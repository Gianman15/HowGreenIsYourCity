# %%
# calls to create census data, note that the dataset headers need to be manually adjusted to fit dataframe
from py_process import ( process_city_pipeline, create_census_geojson,)

#create_census_geojson("raw-data/montreal/9810001402-eng_clean.csv","raw-data/census tracts/lct_000b21a_e.shp")
# i only need this once, my dataset is all of canada but i display only whats needed

# calls for montreal #i will add a function to create meta data for the website to display

# for montreal
#process_city_pipeline("montreal", "D:\Desktop\greenspace_web\py_data_process",LC08_L2SP_014028_20240701_20240711_02_T1_SR_B4.TIF,LC08_L2SP_014028_20240701_20240711_02_T1_SR_B5.TIF)


# for ottawa: -76.00 45.26 -75.29 45.64
bbox_ottawa = (-76.00, 45.26, -75.29, 45.64)
process_city_pipeline("ottawa", r"D:\Desktop\greenspace_web\py_data_process", bbox_ottawa)
# Out:
# Found red band: D:\Desktop\greenspace_web\py_data_process\raw-data\ottawa\landsat2_c2\LC08_L2SP_016028_20250718_20250726_02_T1_SR_B4.TIF
# Found NIR band: D:\Desktop\greenspace_web\py_data_process\raw-data\ottawa\landsat2_c2\LC08_L2SP_016028_20250718_20250726_02_T1_SR_B5.TIF
# Processing city: ottawa
# Scaling complete. Output saved to: D:\Desktop\greenspace_web\py_data_process\raw-data\ottawa\landsat2_c2\scaled_LC08_L2SP_016028_20250718_20250726_02_T1_SR_B4.TIF
# Scaling complete. Output saved to: D:\Desktop\greenspace_web\py_data_process\raw-data\ottawa\landsat2_c2\scaled_LC08_L2SP_016028_20250718_20250726_02_T1_SR_B5.TIF
# d:\Desktop\greenspace_web\py_data_process\py_process.py:48: RuntimeWarning: invalid value encountered in divide
#   ndvi = (nir - red) / (nir + red)
# NDVI calculation complete. Output saved to: D:\Desktop\greenspace_web\py_data_process\raw-data\ottawa\landsat2_c2\ndvi_ottawa.tiff
# Otsu threshold for NDVI: 0.2675791382789612
# Mask saved to: D:\Desktop\greenspace_web\py_data_process\raw-data\ottawa\landsat2_c2\ndvi_ottawa_mask.tiff
# GeoJSON saved to: D:\Desktop\greenspace_web\py_data_process\raw-data\ottawa\greenspace_ndvi_ottawa.geojson
# Using bounding box: (-76.0, 45.26, -75.29, 45.64)
# Clipped GeoJSON saved to output directory: D:\Desktop\greenspace_web\py_data_process\data\ottawa\greenspace_only.geojson
# Clipped GeoJSON also saved to input directory: D:\Desktop\greenspace_web\py_data_process\raw-data\ottawa\greenspace_only.geojson
# Clipped GeoJSON loaded from: D:\Desktop\greenspace_web\py_data_process\raw-data\ottawa\greenspace_only.geojson
# Combined GeoJSON saved to: D:\Desktop\greenspace_web\py_data_process\raw-data\ottawa\greenspace_with_census.geojson
# Combined GeoJSON saved to: D:\Desktop\greenspace_web\py_data_process\raw-data\ottawa\greenspace_capita.geojson
# Greenspace capita data saved to: D:\Desktop\greenspace_web\py_data_process\raw-data\ottawa\greenspace_capita.geojson
# CRS before saving: EPSG:4326
# Final greenspace data saved to: D:\Desktop\greenspace_web\py_data_process\data\ottawa\greenspace_per_capita.geojson
# Pipeline completed for city: ottawa
