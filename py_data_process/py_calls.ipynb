# %%
# calls to create census data, note that the dataset headers need to be manually adjusted to fit dataframe
from py_process import ( process_city_pipeline, create_census_geojson,)

# calls for montreal -74.00 45.35 -73.50 45.75

process_city_pipeline(
     city_name="montreal",
     base_dir=r"B:\greenspace_web\py_data_process",
     census="raw-data/montreal/census_clean.csv",
     census_boundaries="raw-data/montreal/census tracts/census_data/lct_000b21a_e.shp",
     census_div_shapefile="raw-data/montreal/census tracts/census_division/lcd_000a21a_e.shp",
     cduid="2466"  # Montreal's Census Division ID
 )
'''
process_city_pipeline(
     city_name="ottawa",
     base_dir=r"B:\greenspace_web\py_data_process",
     census="raw-data/ottawa/census_clean.csv",
     census_boundaries="raw-data/ottawa/census tracts/census_data/lct_000b21a_e.shp",
     census_div_shapefile="raw-data/ottawa/census tracts/census_division/lcd_000a21a_e.shp",
     cduid="3506"  # Ottawa's Census Division ID
 )
process_city_pipeline(
     city_name="toronto",
     base_dir=r"B:\greenspace_web\py_data_process",
     census="raw-data/toronto/census_clean.csv",
     census_boundaries="raw-data/toronto/census tracts/census_data/lct_000b21a_e.shp",
     census_div_shapefile="raw-data/toronto/census tracts/census_division/lcd_000a21a_e.shp",
     cduid="3520"  # Toronto's Census Division ID
 )
process_city_pipeline(
     city_name="vancouver",
     base_dir=r"B:\greenspace_web\py_data_process",
     census="raw-data/vancouver/census_clean.csv",
     census_boundaries="raw-data/vancouver/census tracts/census_data/lct_000b21a_e.shp",
     census_div_shapefile="raw-data/vancouver/census tracts/census_division/lcd_000a21a_e.shp",
     cduid="5915"  # Vancouver's Census Division ID
 )

# for ottawa: -76.00 45.26 -75.29 45.64
#bbox_ottawa = (-76.00, 45.26, -75.29, 45.64)
#process_city_pipeline("ottawa", r"D:\Desktop\greenspace_web\py_data_process", 
#                       "raw-data/ottawa/census_clean.csv", "raw-data/census tracts/lct_000b21a_e.shp", 
#                       bbox_ottawa)#("ottawa", r"D:\Desktop\greenspace_web\py_data_process", bbox_ottawa)

#for toronto: -80.55 43.39 -78.96 43.86
bbox_toronto = (-80.55, 43.39, -78.96, 43.86)
process_city_pipeline("toronto", r"D:\Desktop\greenspace_web\py_data_process", 
                       "raw-data/toronto/census_clean.csv", "raw-data/census tracts/lct_000b21a_e.shp", 
                       bbox_toronto)#("toronto", r"D:\Desktop\greenspace_web\py_data_process", bbox_toronto)

#for vancouver: -123.19 49.00 -121.78 49.40
bbox_vancouver = (-123.19, 49.00, -121.78, 49.40)
process_city_pipeline("vancouver", r"D:\Desktop\greenspace_web\py_data_process", 
                       "raw-data/vancouver/census_clean.csv", "raw-data/census tracts/lct_000b21a_e.shp", 
                       bbox_vancouver)#("vancouver", r"D:\Desktop\greenspace_web\py_data_process", bbox_vancouver)

'''
# Out:
#         CTUID    pop21    pop16 pop%delt dwelltot    privd  a_land  popdens
# 0  9320001.00  3100.00  3101.00     0.00   723.00   660.00   26.37   117.50
# 1  9320002.00  1226.00  1163.00     5.40   441.00   423.00    8.80   139.40
# 2  9320003.00  7963.00  7248.00     9.90  2790.00  2643.00    2.17  3674.30
# 3  9320004.00  7591.00  7061.00     7.50  2373.00  2216.00    1.90  4004.50
# 4  9320005.01  4019.00  3715.00     8.20  1557.00  1459.00    1.26  3179.10
#         CTUID    pop21  LANDAREA  popdens
# 0  9320001.00  3100.00     26.37   117.50
# 1  9320002.00  1226.00      8.80   139.40
# 2  9320003.00  7963.00      2.17  3674.30
# 3  9320004.00  7591.00      1.90  4004.50
# 4  9320005.01  4019.00      1.26  3179.10
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In[3], line 6
#       2 from py_process import ( process_city_pipeline, create_census_geojson,)
# ...
