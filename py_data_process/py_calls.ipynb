# %%
# calls to create census data, note that the dataset headers need to be manually adjusted to fit dataframe
from py_process import ( process_city_pipeline, create_census_geojson,)

# calls for montreal -74.00 45.35 -73.50 45.75

process_city_pipeline(
     city_name="montreal",
     base_dir=r"B:\greenspace_web\py_data_process",
     census="raw-data/montreal/census_clean.csv",
     census_boundaries="raw-data/census tracts/census_data/lct_000b21a_e.shp",
     census_div_shapefile="raw-data/census tracts/census_division/lcd_000a21a_e.shp",
     cduid="2466"  # Montreal's Census Division ID
 )

process_city_pipeline(
     city_name="ottawa",
     base_dir=r"B:\greenspace_web\py_data_process",
     census="raw-data/ottawa/census_clean.csv",
     census_boundaries="raw-data/census tracts/census_data/lct_000b21a_e.shp",
     census_div_shapefile="raw-data/census tracts/census_division/lcd_000a21a_e.shp",
     cduid="3506"  # Ottawa's Census Division ID
 )
process_city_pipeline(
     city_name="toronto",
     base_dir=r"B:\greenspace_web\py_data_process",
     census="raw-data/toronto/census_clean.csv",
     census_boundaries="raw-data/census tracts/census_data/lct_000b21a_e.shp",
     census_div_shapefile="raw-data/census tracts/census_division/lcd_000a21a_e.shp",
     cduid="3520"  # Toronto's Census Division ID
 )
process_city_pipeline(
     city_name="vancouver",
     base_dir=r"B:\greenspace_web\py_data_process",
     census="raw-data/vancouver/census_clean.csv",
     census_boundaries="raw-data/census tracts/census_data/lct_000b21a_e.shp",
     census_div_shapefile="raw-data/census tracts/census_division/lcd_000a21a_e.shp",
     cduid="5915"  # Vancouver's Census Division ID
 )
'''
# for ottawa: -76.00 45.26 -75.29 45.64


#for toronto: -80.55 43.39 -78.96 43.86


#for vancouver: -123.19 49.00 -121.78 49.40

'''
# Out:
#         CTUID    pop21    pop16 pop%delt dwelltot    privd  a_land  popdens
# 0  9320001.00  3100.00  3101.00     0.00   723.00   660.00   26.37   117.50
# 1  9320002.00  1226.00  1163.00     5.40   441.00   423.00    8.80   139.40
# 2  9320003.00  7963.00  7248.00     9.90  2790.00  2643.00    2.17  3674.30
# 3  9320004.00  7591.00  7061.00     7.50  2373.00  2216.00    1.90  4004.50
# 4  9320005.01  4019.00  3715.00     8.20  1557.00  1459.00    1.26  3179.10
#         CTUID    pop21  LANDAREA  popdens
# 0  9320001.00  3100.00     26.37   117.50
# 1  9320002.00  1226.00      8.80   139.40
# 2  9320003.00  7963.00      2.17  3674.30
# 3  9320004.00  7591.00      1.90  4004.50
# 4  9320005.01  4019.00      1.26  3179.10
# Census tracts GeoJSON saved to: B:\greenspace_web\py_data_process\data\ottawa\censustracts.geojson
# Found red band: B:\greenspace_web\py_data_process\raw-data\ottawa\landsat2_c2\LC08_L2SP_016028_20250718_20250726_02_T1_SR_B4.TIF
# Found NIR band: B:\greenspace_web\py_data_process\raw-data\ottawa\landsat2_c2\LC08_L2SP_016028_20250718_20250726_02_T1_SR_B5.TIF
# Processing city: ottawa
# Scaling complete. Output saved to: B:\greenspace_web\py_data_process\raw-data\ottawa\landsat2_c2\scaled_LC08_L2SP_016028_20250718_20250726_02_T1_SR_B4.TIF
# Scaling complete. Output saved to: B:\greenspace_web\py_data_process\raw-data\ottawa\landsat2_c2\scaled_LC08_L2SP_016028_20250718_20250726_02_T1_SR_B5.TIF
# b:\greenspace_web\py_data_process\py_process.py:54: RuntimeWarning: invalid value encountered in divide
#   ndvi = (nir - red) / (nir + red)
# NDVI calculation complete. Output saved to: B:\greenspace_web\py_data_process\raw-data\ottawa\landsat2_c2\ndvi_ottawa.tiff
# Otsu threshold for NDVI: 0.2675791382789612
# Mask saved to: B:\greenspace_web\py_data_process\raw-data\ottawa\landsat2_c2\ndvi_ottawa_mask.tiff
# GeoJSON saved to: B:\greenspace_web\py_data_process\raw-data\ottawa\greenspace_ndvi_ottawa.geojson
# Clipped GeoJSON saved to: B:\greenspace_web\py_data_process\data\ottawa\greenspace_3506.geojson
# Clipped GeoJSON loaded from: B:\greenspace_web\py_data_process\data\ottawa\greenspace_3506.geojson
# Census GeoJSON loaded from: B:\greenspace_web\py_data_process\data\ottawa\censustracts.geojson
# Number of greenspace polygons before join: 8921
# Total greenspace area before join: 2,244,449,424.49 m²
# Performing overlay intersection (this may take a moment)...
# Number of greenspace polygons after overlay: 9784
# Number of polygons without CTUID match: 0
# Total greenspace area after overlay: 2,244,449,424.16 m²
# Combined GeoJSON saved to: B:\greenspace_web\py_data_process\raw-data\ottawa\greenspace_with_census.geojson
# Total rows in greenspace_with_census: 9784
# Unique census tracts (CTUID): 225
# Rows with null CTUID: 0
# Total greenspace area before groupby: 2,244,449,424.16 m²
# Total greenspace area after groupby: 2,244,449,424.16 m²
# Number of census tracts with greenspace: 225
#
# 📊 Sample greenspace_area values BEFORE geometry merge:
#         CTUID  greenspace_area   LANDAREA
# 0  5050001.04     3.136051e+05  1350000.0
# 1  5050001.05     1.219639e+06  2670000.0
# 2  5050001.06     4.088192e+05  1250000.0
# 3  5050001.07     3.511281e+05   970000.0
# 4  5050001.08     1.553195e+06  4600000.0
# 5  5050001.09     4.403449e+05  1150000.0
# 6  5050001.10     3.580108e+05   910000.0
# 7  5050002.01     2.017989e+06  2590000.0
# 8  5050002.02     8.921053e+05  1520000.0
# 9  5050002.04     9.114761e+05  1190000.0
#
# 📊 Sample greenspace_area values AFTER geometry merge:
#         CTUID  greenspace_area   LANDAREA
# 0  5050001.04     3.136051e+05  1350000.0
# 1  5050001.05     1.219639e+06  2670000.0
# 2  5050001.06     4.088192e+05  1250000.0
# 3  5050001.07     3.511281e+05   970000.0
# 4  5050001.08     1.553195e+06  4600000.0
# 5  5050001.09     4.403449e+05  1150000.0
# 6  5050001.10     3.580108e+05   910000.0
# 7  5050002.01     2.017989e+06  2590000.0
# 8  5050002.02     8.921053e+05  1520000.0
# 9  5050002.04     9.114761e+05  1190000.0
# Greenspace capita data saved to: B:\greenspace_web\py_data_process\raw-data\ottawa\greenspace_capita.geojson
# 📊 Loaded capita file with 225 census tracts
# Total greenspace area in capita file: 2,244,449,424.16 m²
# Greenspace capita data saved to: B:\greenspace_web\py_data_process\raw-data\ottawa\greenspace_capita.geojson
# CRS before saving: EPSG:4326
# Final greenspace data saved to: B:\greenspace_web\py_data_process\data\ottawa\greenspace_per_capita.geojson
# Clipping files to census division: 3506
# ✓ Clipped greenspace_per_capita.geojson saved to: B:\greenspace_web\py_data_process\data\ottawa\greenspace_per_capita.geojson
# ✓ Clipped censustracts.geojson saved to: B:\greenspace_web\py_data_process\data\ottawa\censustracts.geojson
# Clipping completed!
# Pipeline completed for city: ottawa
#         CTUID    pop21    pop16 pop%delt dwelltot    privd  a_land  popdens
# 0  9320001.00  3100.00  3101.00     0.00   723.00   660.00   26.37   117.50
# 1  9320002.00  1226.00  1163.00     5.40   441.00   423.00    8.80   139.40
# 2  9320003.00  7963.00  7248.00     9.90  2790.00  2643.00    2.17  3674.30
# 3  9320004.00  7591.00  7061.00     7.50  2373.00  2216.00    1.90  4004.50
# 4  9320005.01  4019.00  3715.00     8.20  1557.00  1459.00    1.26  3179.10
#         CTUID    pop21  LANDAREA  popdens
# 0  9320001.00  3100.00     26.37   117.50
# 1  9320002.00  1226.00      8.80   139.40
# 2  9320003.00  7963.00      2.17  3674.30
# 3  9320004.00  7591.00      1.90  4004.50
# 4  9320005.01  4019.00      1.26  3179.10
# Census tracts GeoJSON saved to: B:\greenspace_web\py_data_process\data\toronto\censustracts.geojson
# Found red band: B:\greenspace_web\py_data_process\raw-data\toronto\landsat2_c2\LC08_L2SP_018030_20240713_20240719_02_T1_SR_B4.TIF
# Found NIR band: B:\greenspace_web\py_data_process\raw-data\toronto\landsat2_c2\LC08_L2SP_018030_20240713_20240719_02_T1_SR_B5.TIF
# Processing city: toronto
# Scaling complete. Output saved to: B:\greenspace_web\py_data_process\raw-data\toronto\landsat2_c2\scaled_LC08_L2SP_018030_20240713_20240719_02_T1_SR_B4.TIF
# Scaling complete. Output saved to: B:\greenspace_web\py_data_process\raw-data\toronto\landsat2_c2\scaled_LC08_L2SP_018030_20240713_20240719_02_T1_SR_B5.TIF
# b:\greenspace_web\py_data_process\py_process.py:54: RuntimeWarning: invalid value encountered in divide
#   ndvi = (nir - red) / (nir + red)
# NDVI calculation complete. Output saved to: B:\greenspace_web\py_data_process\raw-data\toronto\landsat2_c2\ndvi_toronto.tiff
# Otsu threshold for NDVI: 0.2109183669090271
# Mask saved to: B:\greenspace_web\py_data_process\raw-data\toronto\landsat2_c2\ndvi_toronto_mask.tiff
# GeoJSON saved to: B:\greenspace_web\py_data_process\raw-data\toronto\greenspace_ndvi_toronto.geojson
# Clipped GeoJSON saved to: B:\greenspace_web\py_data_process\data\toronto\greenspace_3520.geojson
# Clipped GeoJSON loaded from: B:\greenspace_web\py_data_process\data\toronto\greenspace_3520.geojson
# Census GeoJSON loaded from: B:\greenspace_web\py_data_process\data\toronto\censustracts.geojson
# Number of greenspace polygons before join: 8639
# Total greenspace area before join: 336,398,438.56 m²
# Performing overlay intersection (this may take a moment)...
# Number of greenspace polygons after overlay: 10221
# Number of polygons without CTUID match: 0
# Total greenspace area after overlay: 335,694,927.21 m²
# ⚠️ WARNING: Area changed by 703,511.35 m² during overlay!
# Combined GeoJSON saved to: B:\greenspace_web\py_data_process\raw-data\toronto\greenspace_with_census.geojson
# Total rows in greenspace_with_census: 10221
# Unique census tracts (CTUID): 618
# Rows with null CTUID: 0
# Total greenspace area before groupby: 335,694,927.21 m²
# Total greenspace area after groupby: 335,694,927.21 m²
# Number of census tracts with greenspace: 618
#
# 📊 Sample greenspace_area values BEFORE geometry merge:
#         CTUID  greenspace_area   LANDAREA
# 0  5350001.00     2.705521e+06  6820000.0
# 1  5350002.00     2.502524e+06  3390000.0
# 2  5350003.00     4.827426e+05   950000.0
# 3  5350004.00     1.662105e+05   340000.0
# 4  5350005.00     1.396413e+05   380000.0
# 5  5350006.00     9.194470e+03    10000.0
# 6  5350007.01     1.089364e+05   200000.0
# 7  5350007.02     7.821560e+04   430000.0
# 8  5350008.01     9.957499e+03   310000.0
# 9  5350008.02     5.707207e+05  1920000.0
#
# 📊 Sample greenspace_area values AFTER geometry merge:
#         CTUID  greenspace_area   LANDAREA
# 0  5350001.00     2.705521e+06  6820000.0
# 1  5350002.00     2.502524e+06  3390000.0
# 2  5350003.00     4.827426e+05   950000.0
# 3  5350004.00     1.662105e+05   340000.0
# 4  5350005.00     1.396413e+05   380000.0
# 5  5350006.00     9.194470e+03    10000.0
# 6  5350007.01     1.089364e+05   200000.0
# 7  5350007.02     7.821560e+04   430000.0
# 8  5350008.01     9.957499e+03   310000.0
# 9  5350008.02     5.707207e+05  1920000.0
# Greenspace capita data saved to: B:\greenspace_web\py_data_process\raw-data\toronto\greenspace_capita.geojson
# 📊 Loaded capita file with 618 census tracts
# Total greenspace area in capita file: 335,694,927.21 m²
# Greenspace capita data saved to: B:\greenspace_web\py_data_process\raw-data\toronto\greenspace_capita.geojson
# CRS before saving: EPSG:4326
# Final greenspace data saved to: B:\greenspace_web\py_data_process\data\toronto\greenspace_per_capita.geojson
# Clipping files to census division: 3520
# ✓ Clipped greenspace_per_capita.geojson saved to: B:\greenspace_web\py_data_process\data\toronto\greenspace_per_capita.geojson
# ✓ Clipped censustracts.geojson saved to: B:\greenspace_web\py_data_process\data\toronto\censustracts.geojson
# Clipping completed!
# Pipeline completed for city: toronto
#         CTUID    pop21    pop16 pop%delt dwelltot    privd  a_land  popdens
# 0  9320001.00  3100.00  3101.00     0.00   723.00   660.00   26.37   117.50
# 1  9320002.00  1226.00  1163.00     5.40   441.00   423.00    8.80   139.40
# 2  9320003.00  7963.00  7248.00     9.90  2790.00  2643.00    2.17  3674.30
# 3  9320004.00  7591.00  7061.00     7.50  2373.00  2216.00    1.90  4004.50
# 4  9320005.01  4019.00  3715.00     8.20  1557.00  1459.00    1.26  3179.10
#         CTUID    pop21  LANDAREA  popdens
# 0  9320001.00  3100.00     26.37   117.50
# 1  9320002.00  1226.00      8.80   139.40
# 2  9320003.00  7963.00      2.17  3674.30
# 3  9320004.00  7591.00      1.90  4004.50
# 4  9320005.01  4019.00      1.26  3179.10
# Census tracts GeoJSON saved to: B:\greenspace_web\py_data_process\data\vancouver\censustracts.geojson
# Found red band: B:\greenspace_web\py_data_process\raw-data\vancouver\landsat2_c2\LC08_L2SP_047026_20250711_20250725_02_T1_SR_B4.TIF
# Found NIR band: B:\greenspace_web\py_data_process\raw-data\vancouver\landsat2_c2\LC08_L2SP_047026_20250711_20250725_02_T1_SR_B5.TIF
# Processing city: vancouver
# Scaling complete. Output saved to: B:\greenspace_web\py_data_process\raw-data\vancouver\landsat2_c2\scaled_LC08_L2SP_047026_20250711_20250725_02_T1_SR_B4.TIF
# Scaling complete. Output saved to: B:\greenspace_web\py_data_process\raw-data\vancouver\landsat2_c2\scaled_LC08_L2SP_047026_20250711_20250725_02_T1_SR_B5.TIF
# b:\greenspace_web\py_data_process\py_process.py:54: RuntimeWarning: invalid value encountered in divide
#   ndvi = (nir - red) / (nir + red)
# NDVI calculation complete. Output saved to: B:\greenspace_web\py_data_process\raw-data\vancouver\landsat2_c2\ndvi_vancouver.tiff
# Otsu threshold for NDVI: 0.17960435152053833
# Mask saved to: B:\greenspace_web\py_data_process\raw-data\vancouver\landsat2_c2\ndvi_vancouver_mask.tiff
# GeoJSON saved to: B:\greenspace_web\py_data_process\raw-data\vancouver\greenspace_ndvi_vancouver.geojson
# Clipped GeoJSON saved to: B:\greenspace_web\py_data_process\data\vancouver\greenspace_5915.geojson
# Clipped GeoJSON loaded from: B:\greenspace_web\py_data_process\data\vancouver\greenspace_5915.geojson
# Census GeoJSON loaded from: B:\greenspace_web\py_data_process\data\vancouver\censustracts.geojson
# Number of greenspace polygons before join: 9575
# Total greenspace area before join: 3,282,765,587.49 m²
# Performing overlay intersection (this may take a moment)...
# Number of greenspace polygons after overlay: 10460
# Number of polygons without CTUID match: 0
# Total greenspace area after overlay: 3,235,111,397.82 m²
# ⚠️ WARNING: Area changed by 47,654,189.66 m² during overlay!
# Combined GeoJSON saved to: B:\greenspace_web\py_data_process\raw-data\vancouver\greenspace_with_census.geojson
# Total rows in greenspace_with_census: 10460
# Unique census tracts (CTUID): 537
# Rows with null CTUID: 0
# Total greenspace area before groupby: 3,235,111,397.82 m²
# Total greenspace area after groupby: 3,235,111,397.82 m²
# Number of census tracts with greenspace: 537
#
# 📊 Sample greenspace_area values BEFORE geometry merge:
#         CTUID  greenspace_area     LANDAREA
# 0  9320014.01     8.327633e-05   83030000.0
# 1  9320014.02     3.841104e-05   15090000.0
# 2  9320206.01     1.315465e-04  162850000.0
# 3  9330001.01     1.126219e+06    1020000.0
# 4  9330001.02     1.801705e+06    1860000.0
# 5  9330002.01     2.061460e+06    1940000.0
# 6  9330002.03     3.138884e+05     790000.0
# 7  9330002.04     5.766960e+05     780000.0
# 8  9330003.01     2.606981e+05     540000.0
# 9  9330003.02     3.589967e+05    1120000.0
#
# 📊 Sample greenspace_area values AFTER geometry merge:
#         CTUID  greenspace_area     LANDAREA
# 0  9320014.01     8.327633e-05   83030000.0
# 1  9320014.02     3.841104e-05   15090000.0
# 2  9320206.01     1.315465e-04  162850000.0
# 3  9330001.01     1.126219e+06    1020000.0
# 4  9330001.02     1.801705e+06    1860000.0
# 5  9330002.01     2.061460e+06    1940000.0
# 6  9330002.03     3.138884e+05     790000.0
# 7  9330002.04     5.766960e+05     780000.0
# 8  9330003.01     2.606981e+05     540000.0
# 9  9330003.02     3.589967e+05    1120000.0
# Greenspace capita data saved to: B:\greenspace_web\py_data_process\raw-data\vancouver\greenspace_capita.geojson
# 📊 Loaded capita file with 537 census tracts
# Total greenspace area in capita file: 3,235,111,397.82 m²
# Greenspace capita data saved to: B:\greenspace_web\py_data_process\raw-data\vancouver\greenspace_capita.geojson
# CRS before saving: EPSG:4326
# Final greenspace data saved to: B:\greenspace_web\py_data_process\data\vancouver\greenspace_per_capita.geojson
# Clipping files to census division: 5915
# ✓ Clipped greenspace_per_capita.geojson saved to: B:\greenspace_web\py_data_process\data\vancouver\greenspace_per_capita.geojson
# ✓ Clipped censustracts.geojson saved to: B:\greenspace_web\py_data_process\data\vancouver\censustracts.geojson
# Clipping completed!
# Pipeline completed for city: vancouver
# '\n# for ottawa: -76.00 45.26 -75.29 45.64\n#bbox_ottawa = (-76.00, 45.26, -75.29, 45.64)\n#process_city_pipeline("ottawa", r"D:\\Desktop\\greenspace_web\\py_data_process", \n#                       "raw-data/ottawa/census_clean.csv", "raw-data/census tracts/lct_000b21a_e.shp", \n#                       bbox_ottawa)#("ottawa", r"D:\\Desktop\\greenspace_web\\py_data_process", bbox_ottawa)\n\n#for toronto: -80.55 43.39 -78.96 43.86\nbbox_toronto = (-80.55, 43.39, -78.96, 43.86)\nprocess_city_pipeline("toronto", r"D:\\Desktop\\greenspace_web\\py_data_process", \n                       "raw-data/toronto/census_clean.csv", "raw-data/census tracts/lct_000b21a_e.shp", \n                       bbox_toronto)#("toronto", r"D:\\Desktop\\greenspace_web\\py_data_process", bbox_toronto)\n\n#for vancouver: -123.19 49.00 -121.78 49.40\nbbox_vancouver = (-123.19, 49.00, -121.78, 49.40)\nprocess_city_pipeline("vancouver", r"D:\\Desktop\\greenspace_web\\py_data_process", \n                       "raw-data/vancouver/census_clean.csv", "raw-data/census tracts/lct_000b21a_e.shp", \n                       bbox_vancouver)#("vancouver", r"D:\\Desktop\\greenspace_web\\py_data_process", bbox_vancouver)\n'
