# %%
# calls to create census data, note that the dataset headers need to be manually adjusted to fit dataframe
from py_process import ( process_city_pipeline, create_census_geojson,)

# calls for montreal -74.00 45.35 -73.50 45.75

#bbox_montreal = (-74.00, 45.35, -73.50, 45.75)
#process_city_pipeline("montreal", r"D:\Desktop\greenspace_web\py_data_process", 
#                       "raw-data/montreal/census_clean.csv", "raw-data/census tracts/lct_000b21a_e.shp", 
#                       bbox_montreal)

# for montreal
#process_city_pipeline("montreal", "D:\Desktop\greenspace_web\py_data_process",LC08_L2SP_014028_20240701_20240711_02_T1_SR_B4.TIF,LC08_L2SP_014028_20240701_20240711_02_T1_SR_B5.TIF)


# for ottawa: -76.00 45.26 -75.29 45.64
#bbox_ottawa = (-76.00, 45.26, -75.29, 45.64)
#process_city_pipeline("ottawa", r"D:\Desktop\greenspace_web\py_data_process", 
#                       "raw-data/ottawa/census_clean.csv", "raw-data/census tracts/lct_000b21a_e.shp", 
#                       bbox_ottawa)#("ottawa", r"D:\Desktop\greenspace_web\py_data_process", bbox_ottawa)


#for toronto: -80.55 43.39 -78.96 43.86
bbox_toronto = (-80.55, 43.39, -78.96, 43.86)
process_city_pipeline("toronto", r"D:\Desktop\greenspace_web\py_data_process", 
                       "raw-data/toronto/census_clean.csv", "raw-data/census tracts/lct_000b21a_e.shp", 
                       bbox_toronto)#("toronto", r"D:\Desktop\greenspace_web\py_data_process", bbox_toronto)

#for vancouver: -123.19 49.00 -121.78 49.40
bbox_vancouver = (-123.19, 49.00, -121.78, 49.40)
process_city_pipeline("vancouver", r"D:\Desktop\greenspace_web\py_data_process", 
                       "raw-data/vancouver/census_clean.csv", "raw-data/census tracts/lct_000b21a_e.shp", 
                       bbox_vancouver)#("vancouver", r"D:\Desktop\greenspace_web\py_data_process", bbox_vancouver)
# Out:
#         CTUID   pop21   pop16  pop%delt  dwelltot   privd  a_land  popdens
# 0  9320001.00  3100.0  3101.0       0.0     723.0   660.0   26.37    117.5
# 1  9320002.00  1226.0  1163.0       5.4     441.0   423.0    8.80    139.4
# 2  9320003.00  7963.0  7248.0       9.9    2790.0  2643.0    2.17   3674.3
# 3  9320004.00  7591.0  7061.0       7.5    2373.0  2216.0    1.90   4004.5
# 4  9320005.01  4019.0  3715.0       8.2    1557.0  1459.0    1.26   3179.1
#         CTUID    pop21  a_land  popdens
# 0  9320001.00  3100.00   26.37   117.50
# 1  9320002.00  1226.00    8.80   139.40
# 2  9320003.00  7963.00    2.17  3674.30
# 3  9320004.00  7591.00    1.90  4004.50
# 4  9320005.01  4019.00    1.26  3179.10
# Census tracts GeoJSON saved to: D:\Desktop\greenspace_web\py_data_process\data\toronto\censustracts.geojson
# Found red band: D:\Desktop\greenspace_web\py_data_process\raw-data\toronto\landsat2_c2\LC08_L2SP_018030_20240713_20240719_02_T1_SR_B4.TIF
# Found NIR band: D:\Desktop\greenspace_web\py_data_process\raw-data\toronto\landsat2_c2\LC08_L2SP_018030_20240713_20240719_02_T1_SR_B5.TIF
# Processing city: toronto
# Scaling complete. Output saved to: D:\Desktop\greenspace_web\py_data_process\raw-data\toronto\landsat2_c2\scaled_LC08_L2SP_018030_20240713_20240719_02_T1_SR_B4.TIF
# Scaling complete. Output saved to: D:\Desktop\greenspace_web\py_data_process\raw-data\toronto\landsat2_c2\scaled_LC08_L2SP_018030_20240713_20240719_02_T1_SR_B5.TIF
# d:\Desktop\greenspace_web\py_data_process\py_process.py:51: RuntimeWarning: invalid value encountered in divide
#   ndvi = (nir - red) / (nir + red)
# NDVI calculation complete. Output saved to: D:\Desktop\greenspace_web\py_data_process\raw-data\toronto\landsat2_c2\ndvi_toronto.tiff
# Otsu threshold for NDVI: 0.2109183669090271
# Mask saved to: D:\Desktop\greenspace_web\py_data_process\raw-data\toronto\landsat2_c2\ndvi_toronto_mask.tiff
# GeoJSON saved to: D:\Desktop\greenspace_web\py_data_process\raw-data\toronto\greenspace_ndvi_toronto.geojson
# Using bounding box: (-80.55, 43.39, -78.96, 43.86)
# Clipped GeoJSON saved to output directory: D:\Desktop\greenspace_web\py_data_process\data\toronto\greenspace_only.geojson
# Clipped GeoJSON also saved to input directory: D:\Desktop\greenspace_web\py_data_process\raw-data\toronto\greenspace_only.geojson
# Clipped GeoJSON loaded from: D:\Desktop\greenspace_web\py_data_process\raw-data\toronto\greenspace_only.geojson
# Census GeoJSON loaded from: D:\Desktop\greenspace_web\py_data_process\data\toronto\censustracts.geojson
